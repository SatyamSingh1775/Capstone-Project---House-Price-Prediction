# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection_v2.csv').drop(columns = ['store room','floor_category','balcony'])

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0    New Property
# 1          flat   sector 89   0.95      2.0       2.0    New Property
# 2          flat  sohna road   0.32      2.0       2.0    New Property
# 3          flat   sector 92   1.60      3.0       4.0  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0  Relatively New
#
#    built_up_area  servant room  furnishing_type luxury_category
# 0          850.0           0.0              0.0             Low
# 1         1226.0           1.0              0.0             Low
# 2         1000.0           0.0              0.0             Low
# 3         1615.0           1.0              1.0            High
# 4          582.0           0.0              0.0            High

# %%
#Plan of the action
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished

# %%
# Numerical = bedRoom, bathroom, built_up_area, servant room
# Ordinal = property_type, furnishing_type, luxury_category 
# OHE = sector, agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1732
# Moderately Old         619
# New Property           599
# Old Property           327
# Under Construction     277
# Name: count, dtype: int64

# %%
df['agePossession'] = df['agePossession'].replace(
    {
    'Relatively New' : 'new',
    'Moderately Old' : 'old',
    'New Property'  : 'new',
    'Old Property'  : 'old',
    'Under Construction'  : 'Under Construction'
})

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# new                   2331
# old                    946
# Under Construction     277
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#      property_type      sector  price  bedRoom  bathroom agePossession  \
# 3549          flat   sector 84   0.37      2.0       2.0           new
# 3550         house  sector 109   6.00      5.0       5.0           new
# 3551          flat    sector 2   0.60      1.0       1.0           old
# 3552         house   sector 43  15.50      5.0       6.0           old
# 3553          flat   sector 68   1.78      3.0       3.0           new
#
#       built_up_area  servant room  furnishing_type luxury_category
# 3549          532.0           0.0              0.0          Medium
# 3550         6228.0           1.0              0.0            High
# 3551          665.0           0.0              1.0          Medium
# 3552         5490.0           1.0              0.0          Medium
# 3553         1845.0           0.0              1.0          Medium

# %%
df['property_type'] = df['property_type'].replace({'flat': 0, 'house':1})
# Out:
# C:\Users\MB511WS\AppData\Local\Temp\ipykernel_20300\1427483964.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['property_type'] = df['property_type'].replace({'flat': 0, 'house':1})

# %%
df.tail()
# Out:
#       property_type      sector  price  bedRoom  bathroom agePossession  \
# 3549              0   sector 84   0.37      2.0       2.0           new
# 3550              1  sector 109   6.00      5.0       5.0           new
# 3551              0    sector 2   0.60      1.0       1.0           old
# 3552              1   sector 43  15.50      5.0       6.0           old
# 3553              0   sector 68   1.78      3.0       3.0           new
#
#       built_up_area  servant room  furnishing_type luxury_category
# 3549          532.0           0.0              0.0          Medium
# 3550         6228.0           1.0              0.0            High
# 3551          665.0           0.0              1.0          Medium
# 3552         5490.0           1.0              0.0          Medium
# 3553         1845.0           0.0              1.0          Medium

# %%
df['luxury_category'].value_counts()
# Out:
# luxury_category
# Low       1594
# Medium    1465
# High       495
# Name: count, dtype: int64

# %%
df['luxury_category'] = df['luxury_category'].replace({'Low':0,'Medium':1, 'High':2})
# Out:
# C:\Users\MB511WS\AppData\Local\Temp\ipykernel_20300\1688724901.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['luxury_category'] = df['luxury_category'].replace({'Low':0,'Medium':1, 'High':2})

# %%
df.tail(7)
# Out:
#       property_type      sector  price  bedRoom  bathroom agePossession  \
# 3547              0  sector 106   0.92      2.0       2.0           new
# 3548              1    sector 6   0.75      4.0       4.0           old
# 3549              0   sector 84   0.37      2.0       2.0           new
# 3550              1  sector 109   6.00      5.0       5.0           new
# 3551              0    sector 2   0.60      1.0       1.0           old
# 3552              1   sector 43  15.50      5.0       6.0           old
# 3553              0   sector 68   1.78      3.0       3.0           new
#
#       built_up_area  servant room  furnishing_type  luxury_category
# 3547          940.0           0.0              0.0                2
# 3548          480.0           0.0              0.0                0
# 3549          532.0           0.0              0.0                1
# 3550         6228.0           1.0              0.0                2
# 3551          665.0           0.0              1.0                1
# 3552         5490.0           1.0              0.0                1
# 3553         1845.0           0.0              1.0                1

# %%
new_df = pd.get_dummies(df , columns = ['sector', 'agePossession'], drop_first = False)

# %%
new_df
# Out:
#       property_type  price  bedRoom  bathroom  built_up_area  servant room  \
# 0                 0   0.82      3.0       2.0          850.0           0.0
# 1                 0   0.95      2.0       2.0         1226.0           1.0
# 2                 0   0.32      2.0       2.0         1000.0           0.0
# 3                 0   1.60      3.0       4.0         1615.0           1.0
# 4                 0   0.48      2.0       2.0          582.0           0.0
# ...             ...    ...      ...       ...            ...           ...
# 3549              0   0.37      2.0       2.0          532.0           0.0
# 3550              1   6.00      5.0       5.0         6228.0           1.0
# 3551              0   0.60      1.0       1.0          665.0           0.0
# 3552              1  15.50      5.0       6.0         5490.0           1.0
# 3553              0   1.78      3.0       3.0         1845.0           0.0
#
#       furnishing_type  luxury_category  sector_dwarka expressway  \
# 0                 0.0                0                     False
# 1                 0.0                0                     False
# 2                 0.0                0                     False
# 3                 1.0                2                     False
# 4                 0.0                2                     False
# ...               ...              ...                       ...
# 3549              0.0                1                     False
# 3550              0.0                2                     False
# 3551              1.0                1                     False
# 3552              0.0                1                     False
# 3553              1.0                1                     False
#
#       sector_gwal pahari  ...  sector_sector 90  sector_sector 91  \
# 0                  False  ...             False             False
# 1                  False  ...             False             False
# 2                  False  ...             False             False
# 3                  False  ...             False             False
# 4                  False  ...             False             False
# ...                  ...  ...               ...               ...
# 3549               False  ...             False             False
# 3550               False  ...             False             False
# 3551               False  ...             False             False
# 3552               False  ...             False             False
# 3553               False  ...             False             False
#
#       sector_sector 92  sector_sector 93  sector_sector 95  sector_sector 99  \
# 0                False             False             False             False
# 1                False             False             False             False
# 2                False             False             False             False
# 3                 True             False             False             False
# 4                False             False             False             False
# ...                ...               ...               ...               ...
# 3549             False             False             False             False
# 3550             False             False             False             False
# 3551             False             False             False             False
# 3552             False             False             False             False
# 3553             False             False             False             False
#
#       sector_sohna road  agePossession_Under Construction  agePossession_new  \
# 0                 False                             False               True
# 1                 False                             False               True
# 2                  True                             False               True
# 3                 False                             False               True
# 4                 False                             False               True
# ...                 ...                               ...                ...
# 3549              False                             False               True
# 3550              False                             False               True
# 3551              False                             False              False
# 3552              False                             False              False
# 3553              False                             False               True
#
#       agePossession_old
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 3549              False
# 3550              False
# 3551               True
# 3552               True
# 3553              False
#
# [3554 rows x 115 columns]

# %%
X = new_df.drop(columns = ['price'])
y = new_df['price']

# %%
y_log = np.log1p(y)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled , columns = X.columns)

# %%
X_scaled
# Out:
#       property_type   bedRoom  bathroom  built_up_area  servant room  \
# 0         -0
# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(LinearRegression(),X_scaled ,y_log ,cv= kfold ,scoring = 'r2')

# %%
scores.mean()
# Out:
# 0.8512613057405425

# %%
scores.std()
# Out:
# 0.016992929105286176

# %%
lr= LinearRegression()
ridge  = Ridge(alpha= 0.0001)

# %%
lr.fit(X_scaled ,y_log)
# Out:
# LinearRegression()

# %%
ridge.fit(X_scaled ,y_log)
# Out:
# Ridge(alpha=0.0001)

# %%
coef_df = pd.DataFrame(ridge.coef_.reshape(1,112),columns=X.columns).stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'feature',0:'coef'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 coef_df = pd.DataFrame(ridge.coef_.reshape(1,112),columns=X.columns).stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'feature',0:'coef'})
#
# ValueError: cannot reshape array of size 114 into shape (1,112)

# %%
# 1. Import necessary libraries
import statsmodels.api as sm

# 2. Add a constant to X
X_with_const = sm.add_constant(X_scaled)

# 3. Fit the model
model = sm.OLS(y_log, X_with_const).fit()

# 4. Obtain summary statistics
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     196.7
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:07:09   Log-Likelihood:                 588.22
# No. Observations:                3554   AIC:                            -950.4
# Df Residuals:                    3441   BIC:                            -252.6
# Df Model:                         112
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                1.0464      0.003    299.336      0.000       1.040       1.053
# property_type                        0.1202      0.005     22.829      0.000       0.110       0.130
# bedRoom                              0.0540      0.007      8.196      0.000       0.041       0.067
# bathroom                             0.0651      0.007      9.554      0.000       0.052       0.078
# built_up_area                        0.2106      0.005     41.763      0.000       0.201       0.221
# servant room                         0.0509      0.005     11.231      0.000       0.042       0.060
# furnishing_type                      0.0083      0.004      2.038      0.042       0.000       0.016
# luxury_category                      0.0062      0.004      1.534      0.125      -0.002       0.014
# sector_dwarka expressway            -0.0054      0.004     -1.526      0.127      -0.012       0.002
# sector_gwal pahari                   0.0018      0.004      0.508      0.611      -0.005       0.009
# sector_manesar                      -0.0332      0.004     -9.413      0.000      -0.040      -0.026
# sector_sector 1                     -0.0098      0.004     -2.808      0.005      -0.017      -0.003
# sector_sector 10                     0.0002      0.004      0.063      0.950      -0.007       0.007
# sector_sector 102                    0.0076      0.003      2.207      0.027       0.001       0.014
# sector_sector 103                   -0.0151      0.003     -4.359      0.000      -0.022      -0.008
# sector_sector 104                   -0.0134      0.003     -3.876      0.000      -0.020      -0.007
# sector_sector 105                   -0.0279      0.004     -7.796      0.000      -0.035      -0.021
# sector_sector 106                   -0.0111      0.004     -3.162      0.002      -0.018      -0.004
# sector_sector 107                   -0.0275      0.003     -7.869      0.000      -0.034      -0.021
# sector_sector 108                    0.0025      0.003      0.712      0.477      -0.004       0.009
# sector_sector 109                    0.0087      0.004      2.489      0.013       0.002       0.016
# sector_sector 11                    -0.0225      0.004     -6.346      0.000      -0.030      -0.016
# sector_sector 110                   -0.0003      0.003     -0.099      0.921      -0.007       0.006
# sector_sector 111                    0.0073      0.003      2.104      0.035       0.000       0.014
# sector_sector 112                    0.0217      0.004      6.174      0.000       0.015       0.029
# sector_sector 113                    0.0198      0.004      5.653      0.000       0.013       0.027
# sector_sector 12                    -0.0302      0.004     -8.485      0.000      -0.037      -0.023
# sector_sector 13                    -0.0179      0.004     -5.044      0.000      -0.025      -0.011
# sector_sector 14                     0.0207      0.004      5.826      0.000       0.014       0.028
# sector_sector 15                    -0.0014      0.004     -0.387      0.698      -0.008       0.006
# sector_sector 17                     0.0079      0.004      2.235      0.025       0.001       0.015
# sector_sector 2                     -0.0080      0.004     -2.244      0.025      -0.015      -0.001
# sector_sector 21                    -0.0141      0.004     -4.008      0.000      -0.021      -0.007
# sector_sector 66                     0.0407      0.004     11.627      0.000       0.034       0.048
# sector_sector 67                     0.0280      0.003      8.041      0.000       0.021       0.035
# sector_sector 67a                -8.701e-07      0.003     -0.000      1.000      -0.007       0.007
# sector_sector 68                     0.0006      0.003      0.164      0.869      -0.006       0.007
# sector_sector 69                     0.0003      0.004      0.099      0.921      -0.007       0.007
# sector_sector 7                     -0.0185      0.004     -5.114      0.000      -0.026      -0.011
# sector_sector 70                    -0.0077      0.003     -2.200      0.028      -0.015      -0.001
# sector_sector 70a                    0.0033      0.003      0.956      0.339      -0.003       0.010
# sector_sector 71                    -0.0131      0.003     -3.754      0.000      -0.020      -0.006
# sector_sector 72                     0.0200      0.004      5.717      0.000       0.013       0.027
# sector_sector 73                    -0.0047      0.004     -1.349      0.177      -0.012       0.002
# sector_sector 74                     0.0141      0.004      4.035      0.000       0.007       0.021
# sector_sector 76                    -0.0071      0.004     -2.012      0.044      -0.014      -0.000
# sector_sector 77                    -0.0091      0.003     -2.593      0.010      -0.016      -0.002
# sector_sector 78                    -0.0119      0.004     -3.390      0.001      -0.019      -0.005
# sector_sector 79                    -0.0032      0.003     -0.925      0.355      -0.010       0.004
# sector_sector 8                     -0.0185      0.004     -5.226      0.000      -0.025      -0.012
# sector_sector 80                    -0.0040      0.004     -1.155      0.248      -0.011       0.003
# sector_sector 81                    -0.0018      0.004     -0.517      0.605      -0.009       0.005
# sector_sector 82                    -0.0115      0.003     -3.316      0.001      -0.018      -0.005
# sector_sector 82a                    0.0015      0.003      0.427      0.669      -0.005       0.008
# sector_sector 83                    -0.0166      0.003     -4.776      0.000      -0.023      -0.010
# sector_sector 84                    -0.0235      0.003     -6.745      0.000      -0.030      -0.017
# sector_sector 85                    -0.0107      0.003     -3.088      0.002      -0.017      -0.004
# sector_sector 86                    -0.0185      0.003     -5.362      0.000      -0.025      -0.012
# sector_sector 88                    -0.0033      0.003     -0.957      0.339      -0.010       0.004
# sector_sector 88a                   -0.0003      0.003     -0.080      0.936      -0.007       0.007
# sector_sector 89                    -0.0122      0.004     -3.471      0.001      -0.019      -0.005
# sector_sector 9                     -0.0222      0.004     -6.256      0.000      -0.029      -0.015
# sector_sector 90                    -0.0307      0.003     -8.888      0.000      -0.037      -0.024
# sector_sector 91                    -0.0079      0.003     -2.278      0.023      -0.015      -0.001
# sector_sector 92                    -0.0473      0.003    -13.679      0.000      -0.054      -0.041
# sector_sector 93                    -0.0097      0.003     -2.763      0.006      -0.017      -0.003
# sector_sector 95                    -0.0392      0.004    -11.167      0.000      -0.046      -0.032
# sector_sector 99                    -0.0225      0.003     -6.457      0.000      -0.029      -0.016
# sector_sohna road                   -0.0532      0.003    -15.228      0.000      -0.060      -0.046
# agePossession_Under Construction     0.0150      0.004      4.245      0.000       0.008       0.022
# agePossession_new                   -0.0006      0.002     -0.248      0.805      -0.005       0.004
# agePossession_old                   -0.0085      0.003     -2.765      0.006      -0.014      -0.002
# ==============================================================================
# Omnibus:                      514.316   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4724.056
# Skew:                          -0.385   Prob(JB):                         0.00
# Kurtosis:                       8.595   Cond. No.                     2.81e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.67e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
